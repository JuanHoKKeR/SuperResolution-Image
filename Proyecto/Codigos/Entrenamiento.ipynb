# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, Conv2DTranspose, PReLU, Input
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.preprocessing.image import img_to_array, load_img
from datetime import datetime
import matplotlib.pyplot as plt
from skimage.metrics import peak_signal_noise_ratio as psnr
from skimage.metrics import structural_similarity as ssim

# %%
# Define la función FSRCNN
def FSRCNN(scale_factor, input_shape=(64, 64, 1)):
    inputs = Input(shape=input_shape)

    # Feature extraction
    x = Conv2D(56, (5, 5), padding='same')(inputs)
    x = PReLU()(x)
    
    # Shrinking
    x = Conv2D(12, (1, 1), padding='same')(x)
    x = PReLU()(x)
    
    # Non-linear mapping
    for _ in range(4):
        x = Conv2D(12, (3, 3), padding='same')(x)
        x = PReLU()(x)
    
    # Expanding
    x = Conv2D(56, (1, 1), padding='same')(x)
    x = PReLU()(x)
    
    # Deconvolution
    x = Conv2DTranspose(1, (9, 9), strides=(scale_factor, scale_factor), padding='same')(x)
    outputs = PReLU()(x)
    
    model = Model(inputs, outputs)
    return model

# %%
# Crear el modelo FSRCNN
model = FSRCNN(scale_factor=16, input_shape=(64, 64, 1))
model.compile(optimizer=Adam(learning_rate=0.001), loss=MeanSquaredError())

# %%
# Preparar datos para el entrenamiento
def load_dataset(low_res_dir, high_res_dir):
    low_res_images = []
    high_res_images = []

    for filename in os.listdir(low_res_dir):
        low_res_image_path = os.path.join(low_res_dir, filename)
        high_res_image_name = filename.split('_blur')[0].split('_64x64')[0] + '.png'
        high_res_image_path = os.path.join(high_res_dir, high_res_image_name)
        
        # Verificar si el archivo de alta resolución existe
        if os.path.exists(high_res_image_path):
            low_res_image = load_img(low_res_image_path, color_mode='grayscale')
            high_res_image = load_img(high_res_image_path, color_mode='grayscale')

            low_res_images.append(img_to_array(low_res_image) / 255.0)
            high_res_images.append(img_to_array(high_res_image) / 255.0)
        else:
            print(f"Archivo de alta resolución no encontrado para: {low_res_image_path}")

    return np.array(low_res_images), np.array(high_res_images)

# Cargar los datos
base_dir = r'C:\Users\lina-\Documents\ProyectoComputacion\Proyecto\dataset'
x_train, y_train = load_dataset(os.path.join(base_dir, 'train/low_res'), os.path.join(base_dir, 'train/high_res'))
x_val, y_val = load_dataset(os.path.join(base_dir, 'validation/low_res'), os.path.join(base_dir, 'validation/high_res'))

# Asegurarse de que los datos tienen la forma correcta
x_train = x_train.reshape(-1, 64, 64, 1)
y_train = y_train.reshape(-1, 1024, 1024, 1)
x_val = x_val.reshape(-1, 64, 64, 1)
y_val = y_val.reshape(-1, 1024, 1024, 1)

# %%
# Callbacks para el entrenamiento
log_dir = "logs/fit/" + datetime.now().strftime("%Y%m%d-%H%M%S")
os.makedirs(log_dir, exist_ok=True)
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='best_model.keras',
    save_best_only=True,
    monitor='val_loss',
    mode='min',
    verbose=1
)

# %%
# Callback personalizado para monitorear PSNR y SSIM
class MonitorPSNRandSSIM(tf.keras.callbacks.Callback):
    def __init__(self, validation_data):
        super(MonitorPSNRandSSIM, self).__init__()
        self.validation_data = validation_data

    def on_epoch_end(self, epoch, logs=None):
        val_x, val_y = self.validation_data
        val_y_pred = self.model.predict(val_x)

        psnr_values = [psnr(val_y[i], val_y_pred[i], data_range=1.0) for i in range(len(val_y))]
        ssim_values = [ssim(val_y[i].reshape(1024, 1024), val_y_pred[i].reshape(1024, 1024), data_range=1.0) for i in range(len(val_y))]

        mean_psnr = np.mean(psnr_values)
        mean_ssim = np.mean(ssim_values)

        print(f"Epoch {epoch+1}: PSNR: {mean_psnr:.4f}, SSIM: {mean_ssim:.4f}")

# %%
# Entrenar el modelo con más información
history = model.fit(
    x_train, y_train,
    validation_data=(x_val, y_val),
    epochs=50,
    batch_size=16,
    callbacks=[tensorboard_callback, checkpoint_callback, MonitorPSNRandSSIM((x_val, y_val))]
)
# Out:
# Epoch 1/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step - loss: 0.0484
# Epoch 1: val_loss improved from 0.04798 to 0.04717, saving model to best_model.keras
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 207ms/step
# Epoch 1: PSNR: 13.5200, SSIM: 0.2462
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 73s 1s/step - loss: 0.0484 - val_loss: 0.0472
# Epoch 2/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - loss: 0.0480
# Epoch 2: val_loss improved from 0.04717 to 0.04678, saving model to best_model.keras
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 195ms/step
# Epoch 2: PSNR: 13.5370, SSIM: 0.2506
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 58s 945ms/step - loss: 0.0481 - val_loss: 0.0468
# Epoch 3/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - loss: 0.0471
# Epoch 3: val_loss improved from 0.04678 to 0.04662, saving model to best_model.keras
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 196ms/step
# Epoch 3: PSNR: 13.5396, SSIM: 0.2493
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 62s 1s/step - loss: 0.0471 - val_loss: 0.0466
# Epoch 4/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 274ms/step - loss: 0.0473
# Epoch 4: val_loss improved from 0.04662 to 0.04657, saving model to best_model.keras
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step
# Epoch 4: PSNR: 13.5354, SSIM: 0.2507
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 61s 991ms/step - loss: 0.0473 - val_loss: 0.0466
# Epoch 5/50
# 61/62 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step - loss: 0.0475
# Epoch 5: val_loss did not improve from 0.04657
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 205ms/step
# Epoch 5: PSNR: 13.5304, SSIM: 0.2518
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 60s 984ms/step - loss: 0.0475 - val_loss: 0.0466
# Epoch 6/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - loss: 0.0471
# Epoch 6: val_loss did not improve from 0.04657
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 208ms/step
# Epoch 6: PSNR: 13.5230, SSIM: 0.2537
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 63s 1s/step - loss: 0.0471 - val_loss: 0.0466
# Epoch 7/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step - loss: 0.0463
# Epoch 7: val_loss did not improve from 0.04657
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 209ms/step
# Epoch 7: PSNR: 13.5179, SSIM: 0.2541
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 61s 990ms/step - loss: 0.0463 - val_loss: 0.0467
# Epoch 8/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step - loss: 0.0465
# Epoch 8: val_loss did not improve from 0.04657
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 204ms/step
# Epoch 8: PSNR: 13.5119, SSIM: 0.2540
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 60s 984ms/step - loss: 0.0465 - val_loss: 0.0467
# Epoch 9/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 279ms/step - loss: 0.0465
# Epoch 9: val_loss did not improve from 0.04657
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 207ms/step
# Epoch 9: PSNR: 13.5091, SSIM: 0.2537
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 61s 988ms/step - loss: 0.0465 - val_loss: 0.0467
# Epoch 10/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step - loss: 0.0466
# Epoch 10: val_loss did not improve from 0.04657
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 204ms/step
# Epoch 10: PSNR: 13.5071, SSIM: 0.2545
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 61s 987ms/step - loss: 0.0466 - val_loss: 0.0467
# Epoch 11/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 279ms/step - loss: 0.0470
# Epoch 11: val_loss did not improve from 0.04657
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 205ms/step
# Epoch 11: PSNR: 13.5056, SSIM: 0.2542
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 60s 984ms/step - loss: 0.0470 - val_loss: 0.0467
# Epoch 12/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - loss: 0.0473
# Epoch 12: val_loss did not improve from 0.04657
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 204ms/step
# Epoch 12: PSNR: 13.5044, SSIM: 0.2520
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 60s 983ms/step - loss: 0.0473 - val_loss: 0.0468
# Epoch 13/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - loss: 0.0472
# Epoch 13: val_loss did not improve from 0.04657
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 215ms/step
# Epoch 13: PSNR: 13.5065, SSIM: 0.2546
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 60s 971ms/step - loss: 0.0472 - val_loss: 0.0467
# Epoch 14/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step - loss: 0.0478
# Epoch 14: val_loss did not improve from 0.04657
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 205ms/step
# Epoch 14: PSNR: 13.5043, SSIM: 0.2563
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 58s 944ms/step - loss: 0.0478 - val_loss: 0.0468
# Epoch 15/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - loss: 0.0473
# Epoch 15: val_loss did not improve from 0.04657
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 205ms/step
# Epoch 15: PSNR: 13.5032, SSIM: 0.2550
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 58s 938ms/step - loss: 0.0473 - val_loss: 0.0468
# Epoch 16/50
# 61/62 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step - loss: 0.0465
# Epoch 16: val_loss did not improve from 0.04657
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 205ms/step
# Epoch 16: PSNR: 13.5035, SSIM: 0.2549
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 58s 938ms/step - loss: 0.0465 - val_loss: 0.0468
# Epoch 17/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - loss: 0.0458
# Epoch 17: val_loss did not improve from 0.04657
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 205ms/step
# Epoch 17: PSNR: 13.5048, SSIM: 0.2553
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 58s 938ms/step - loss: 0.0458 - val_loss: 0.0468
# Epoch 18/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - loss: 0.0462
# Epoch 18: val_loss did not improve from 0.04657
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 202ms/step
# Epoch 18: PSNR: 13.5059, SSIM: 0.2548
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 58s 938ms/step - loss: 0.0462 - val_loss: 0.0467
# Epoch 19/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - loss: 0.0472
# Epoch 19: val_loss did not improve from 0.04657
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 206ms/step
# Epoch 19: PSNR: 13.5077, SSIM: 0.2531
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 349s 6s/step - loss: 0.0472 - val_loss: 0.0467
# Epoch 20/50
# 61/62 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - loss: 0.0469
# Epoch 20: val_loss did not improve from 0.04657
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step
# Epoch 20: PSNR: 13.5103, SSIM: 0.2539
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 59s 960ms/step - loss: 0.0469 - val_loss: 0.0467
# Epoch 21/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step - loss: 0.0471
# Epoch 21: val_loss did not improve from 0.04657
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 204ms/step
# Epoch 21: PSNR: 13.5071, SSIM: 0.2546
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 60s 976ms/step - loss: 0.0471 - val_loss: 0.0467
# Epoch 22/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step - loss: 0.0467
# Epoch 22: val_loss did not improve from 0.04657
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 205ms/step
# Epoch 22: PSNR: 13.5094, SSIM: 0.2545
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 60s 985ms/step - loss: 0.0467 - val_loss: 0.0467
# Epoch 23/50
# 61/62 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step - loss: 0.0465
# Epoch 23: val_loss did not improve from 0.04657
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 202ms/step
# Epoch 23: PSNR: 13.5072, SSIM: 0.2536
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 58s 940ms/step - loss: 0.0465 - val_loss: 0.0467
# Epoch 24/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - loss: 0.0464
# Epoch 24: val_loss did not improve from 0.04657
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 205ms/step
# Epoch 24: PSNR: 13.5078, SSIM: 0.2549
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 61s 1s/step - loss: 0.0464 - val_loss: 0.0467
# Epoch 25/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - loss: 0.0465
# Epoch 25: val_loss did not improve from 0.04657
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 197ms/step
# Epoch 25: PSNR: 13.5070, SSIM: 0.2540
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 59s 968ms/step - loss: 0.0465 - val_loss: 0.0467
# Epoch 26/50
# 61/62 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step - loss: 0.0474
# Epoch 26: val_loss did not improve from 0.04657
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step
# Epoch 26: PSNR: 13.5071, SSIM: 0.2537
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 58s 946ms/step - loss: 0.0474 - val_loss: 0.0467
# Epoch 27/50
# 61/62 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step - loss: 0.0463
# Epoch 27: val_loss did not improve from 0.04657
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 201ms/step
# Epoch 27: PSNR: 13.5048, SSIM: 0.2557
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 58s 943ms/step - loss: 0.0463 - val_loss: 0.0467
# Epoch 28/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step - loss: 0.0464
# Epoch 28: val_loss did not improve from 0.04657
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 203ms/step
# Epoch 28: PSNR: 13.5091, SSIM: 0.2554
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 61s 987ms/step - loss: 0.0464 - val_loss: 0.0467
# Epoch 29/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step - loss: 0.0480
# Epoch 29: val_loss did not improve from 0.04657
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 212ms/step
# Epoch 29: PSNR: 13.5076, SSIM: 0.2544
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 62s 1s/step - loss: 0.0480 - val_loss: 0.0467
# Epoch 30/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step - loss: 0.0471
# Epoch 30: val_loss did not improve from 0.04657
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 205ms/step
# Epoch 30: PSNR: 13.5111, SSIM: 0.2548
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 60s 981ms/step - loss: 0.0471 - val_loss: 0.0467
# Epoch 31/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step - loss: 0.0465
# Epoch 31: val_loss did not improve from 0.04657
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 208ms/step
# Epoch 31: PSNR: 13.5140, SSIM: 0.2544
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 61s 997ms/step - loss: 0.0465 - val_loss: 0.0467
# Epoch 32/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step - loss: 0.0467
# Epoch 32: val_loss did not improve from 0.04657
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 207ms/step
# Epoch 32: PSNR: 13.5119, SSIM: 0.2562
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 61s 997ms/step - loss: 0.0467 - val_loss: 0.0467
# Epoch 33/50
# 61/62 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step - loss: 0.0472
# Epoch 33: val_loss did not improve from 0.04657
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 209ms/step
# Epoch 33: PSNR: 13.5089, SSIM: 0.2558
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 62s 1s/step - loss: 0.0472 - val_loss: 0.0467
# Epoch 34/50
# 61/62 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step - loss: 0.0463
# Epoch 34: val_loss did not improve from 0.04657
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 208ms/step
# Epoch 34: PSNR: 13.5107, SSIM: 0.2549
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 61s 1s/step - loss: 0.0463 - val_loss: 0.0467
# Epoch 35/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step - loss: 0.0468
# Epoch 35: val_loss did not improve from 0.04657
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 207ms/step
# Epoch 35: PSNR: 13.5113, SSIM: 0.2553
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 60s 981ms/step - loss: 0.0468 - val_loss: 0.0467
# Epoch 36/50
# 61/62 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step - loss: 0.0464
# Epoch 36: val_loss did not improve from 0.04657
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 203ms/step
# Epoch 36: PSNR: 13.5081, SSIM: 0.2558
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 143s 2s/step - loss: 0.0464 - val_loss: 0.0467
# Epoch 37/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - loss: 0.0470
# Epoch 37: val_loss did not improve from 0.04657
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 195ms/step
# Epoch 37: PSNR: 13.5097, SSIM: 0.2542
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 61s 995ms/step - loss: 0.0470 - val_loss: 0.0467
# Epoch 38/50
# 61/62 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step - loss: 0.0462
# Epoch 38: val_loss did not improve from 0.04657
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 198ms/step
# Epoch 38: PSNR: 13.5087, SSIM: 0.2552
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 58s 947ms/step - loss: 0.0463 - val_loss: 0.0467
# Epoch 39/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - loss: 0.0459
# Epoch 39: val_loss did not improve from 0.04657
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step
# Epoch 39: PSNR: 13.5077, SSIM: 0.2549
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 62s 1s/step - loss: 0.0459 - val_loss: 0.0467
# Epoch 40/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step - loss: 0.0474
# Epoch 40: val_loss did not improve from 0.04657
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 214ms/step
# Epoch 40: PSNR: 13.5084, SSIM: 0.2547
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 62s 1s/step - loss: 0.0474 - val_loss: 0.0467
# Epoch 41/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - loss: 0.0470
# Epoch 41: val_loss did not improve from 0.04657
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 226ms/step
# Epoch 41: PSNR: 13.5131, SSIM: 0.2550
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 59s 960ms/step - loss: 0.0470 - val_loss: 0.0467
# Epoch 42/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - loss: 0.0467
# Epoch 42: val_loss did not improve from 0.04657
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 197ms/step
# Epoch 42: PSNR: 13.5126, SSIM: 0.2548
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 60s 984ms/step - loss: 0.0467 - val_loss: 0.0467
# Epoch 43/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step - loss: 0.0467
# Epoch 43: val_loss did not improve from 0.04657
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 202ms/step
# Epoch 43: PSNR: 13.5101, SSIM: 0.2538
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 60s 985ms/step - loss: 0.0467 - val_loss: 0.0467
# Epoch 44/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - loss: 0.0475
# Epoch 44: val_loss did not improve from 0.04657
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 202ms/step
# Epoch 44: PSNR: 13.5045, SSIM: 0.2562
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 61s 993ms/step - loss: 0.0475 - val_loss: 0.0467
# Epoch 45/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step - loss: 0.0472
# Epoch 45: val_loss did not improve from 0.04657
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 208ms/step
# Epoch 45: PSNR: 13.5121, SSIM: 0.2556
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 62s 1s/step - loss: 0.0472 - val_loss: 0.0467
# Epoch 46/50
# 61/62 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step - loss: 0.0472
# Epoch 46: val_loss did not improve from 0.04657
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 212ms/step
# Epoch 46: PSNR: 13.5062, SSIM: 0.2523
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 61s 1s/step - loss: 0.0472 - val_loss: 0.0467
# Epoch 47/50
# 61/62 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step - loss: 0.0465
# Epoch 47: val_loss did not improve from 0.04657
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 208ms/step
# Epoch 47: PSNR: 13.5090, SSIM: 0.2549
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 62s 1s/step - loss: 0.0465 - val_loss: 0.0467
# Epoch 48/50
# 61/62 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step - loss: 0.0466
# Epoch 48: val_loss did not improve from 0.04657
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 207ms/step
# Epoch 48: PSNR: 13.5137, SSIM: 0.2554
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 60s 983ms/step - loss: 0.0466 - val_loss: 0.0467
# Epoch 49/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step - loss: 0.0471
# Epoch 49: val_loss did not improve from 0.04657
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 215ms/step
# Epoch 49: PSNR: 13.5065, SSIM: 0.2534
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 59s 964ms/step - loss: 0.0471 - val_loss: 0.0467
# Epoch 50/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - loss: 0.0461
# Epoch 50: val_loss did not improve from 0.04657
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 209ms/step
# Epoch 50: PSNR: 13.5077, SSIM: 0.2542
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 61s 991ms/step - loss: 0.0461 - val_loss: 0.0467

# %%
# Evaluar el modelo
x_test, y_test = load_dataset(os.path.join(base_dir, 'validation/low_res'), os.path.join(base_dir, 'validation/high_res'))
x_test = x_test.reshape(-1, 64, 64, 1)
y_test = y_test.reshape(-1, 1024, 1024, 1)
loss = model.evaluate(x_test, y_test)
print(f'Loss en el conjunto de prueba: {loss}')

# Función para predecir y mostrar resultados
def predict_and_show(model, x_test, y_test, num_images=5):
    predictions = model.predict(x_test[:num_images])

    for i in range(num_images):
        low_res_image = x_test[i].reshape(64, 64)
        high_res_image = y_test[i].reshape(1024, 1024)
        predicted_image = predictions[i].reshape(1024, 1024)

        plt.figure(figsize=(15, 5))

        plt.subplot(1, 3, 1)
        plt.title('Low Resolution')
        plt.imshow(low_res_image, cmap='gray')
        plt.axis('off')

        plt.subplot(1, 3, 2)
        plt.title('Predicted High Resolution')
        plt.imshow(predicted_image, cmap='gray')
        plt.axis('off')

        plt.subplot(1, 3, 3)
        plt.title('Original High Resolution')
        plt.imshow(high_res_image, cmap='gray')
        plt.axis('off')

        plt.show()

# Predecir y mostrar resultados
predict_and_show(model, x_test, y_test, num_images=5)
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 213ms/step - loss: 0.0482
# Loss en el conjunto de prueba: 0.046719424426555634
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step

# %%
from PIL import Image
import matplotlib.pyplot as plt

# Ruta al archivo cargado
image_path = '/mnt/data/image.png'

# Cargar y mostrar la imagen
image = Image.open(image_path)
plt.imshow(image)
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[17], line 8
#       5 image_path = '/mnt/data/image.png'
#       7 # Cargar y mostrar la imagen
# ----> 8 image = Image.open(image_path)
#       9 plt.imshow(image)
#      10 plt.axis('off')
#
# File c:\Users\lina-\Documents\ProyectoComputacion\venv\Lib\site-packages\PIL\Image.py:3247, in open(fp, mode, formats)
#    3244     filename = fp
#    3246 if filename:
# -> 3247     fp = builtins.open(filename, "rb")
#    3248     exclusive_fp = True
#    3250 try:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/mnt/data/image.png'
